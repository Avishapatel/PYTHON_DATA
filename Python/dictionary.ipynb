# %%
# used to store data value in KEY:VALUE pairs.
# created using "{}".
# key must be unique , value duplication allow
# indexing supporting

# %%
d={
    "name":"Avisha",
    "age":25,
    "Conatct_No":8574859685
}
print(d)
# Out:
# {'name': 'Avisha', 'age': 25, 'Conatct_No': 8574859685}

# %%
x = {'a' : [ 1,2,3] , 'b':(1,2,3) , 'c' : {1,2,3} }
print(x)
print(x.get('a'))
print(x['a'])
# Out:
# {'a': [1, 2, 3], 'b': (1, 2, 3), 'c': {1, 2, 3}}
# [1, 2, 3]
# [1, 2, 3]

# %%
# Multi Dictionary
a={
    'aadhya':
    {'height':5.6 , 'weight':64},
    'Divya':
        {'height':6.1 , 'weight':58},
}
print(a['aadhya']['height'])
# Out:
# 5.6

# %%
d = { 'a':123 , 'b':45 , 'c':12 }
d['c']=20
print(d)
# Out:
# {'a': 123, 'b': 45, 'c': 20}

# %%
e={
    'a':15,'b':20,'c':'Name'
}
# d.popitem()
# d.clear()
# print(d)
R=e.pop("a")
print(R)
print(e)
# Out:
# 15
# {'b': 20, 'c': 'Name'}

# %%
d={
    "name":"Avisha",
    "Age":25,
    "Address":"Surat"
}
print(d.keys())
print(d.values())
print(d.items())
d.update({'Contact_No':85748596857})
print(d)
# Out:
# dict_keys(['name', 'Age', 'Address'])
# dict_values(['Avisha', 25, 'Surat'])
# dict_items([('name', 'Avisha'), ('Age', 25), ('Address', 'Surat')])
# {'name': 'Avisha', 'Age': 25, 'Address': 'Surat', 'Contact_No': 85748596857}

# %%
name={'Aadhya',"Divya","Meera"}
hobbies={'Singing','Dancing'}
d=dict.fromkeys(name,hobbies)
print(d)
# Out:
# {'Aadhya': {'Singing', 'Dancing'}, 'Divya': {'Singing', 'Dancing'}, 'Meera': {'Singing', 'Dancing'}}
