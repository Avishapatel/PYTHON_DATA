# %%
import math
a=math.sin(math.radians(2))
print(a)



# import math

# Brings in Python’s built-in math module, which contains many mathematical functions (like sin, cos, sqrt, etc.).

# math.radians(2)

# The sin() function in Python requires input in radians, not degrees.

# math.radians(x) converts degrees → radians.

# math.radians(2) = 
# 2
# ×
# 𝜋
# /
# 180
# 2×π/180
# = 0.034906585 radians

# math.sin(0.034906585)

# Now sin() is applied to the radian value.

# sin(0.034906585) ≈ 0.0348994967

# Store in variable a

# So, a = 0.0348994967
# Out:
# 0.03489949670250097

# %%
import math
b=math.cos(60)
print(b)
# Out:
# -0.9524129804151563

# %%
b=math.sqrt(64)
print(b)
# Out:
# 8.0

# %%
    #Round a number upward to its nearest integer
print(math.ceil(0.4))
print(math.ceil(1.6))
print(math.ceil(1.4))
# Out:
# 1
# 2
# 2

# %%
# Round numbers down to the nearest integer
print(math.floor(1.6))
print(math.floor(2.8))
print(math.floor(3.8))
print(math.floor(2.4))
# Out:
# 1
# 2
# 3
# 2

# %%
print(math.factorial(3))
print(math.factorial(5)) #  5*4*3*2*1
# Out:
# 6
# 120

# %%
math.pi
# Out:
# 3.141592653589793

# %%
x=math.pow(3,3)
print(x)
# Out:
# 27.0

# %%
import random
a=random.randint(1,1000)
print(a)
# Out:
# 328

# %%
import random
b=["banana","mango","kiwi","apple"]
ans=random.choice(b)
print(ans)
# Out:
# kiwi
