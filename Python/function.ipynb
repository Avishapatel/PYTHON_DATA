# %%
# why we defin function?
# - difine function def keyword
# -code reusablity
# -simplify main program
# -proper arranging of code
# -easy to understand
# -reduce size and memory of code

# %%
# Python support two types of functions :-  1. Built-in function
#                                           2. User-defined function

# The functions which are come along with Python itself are called a built-in function or predefined function. 
# Some of them are listed : range(), id(), type(), input(), eval() etc.

# Functions which are created by programmer explicitly according to the requirement are called a user-defined function.

# %%
# def function_name(parameter1, parameter2):
#          # function body    
#          # write some action
# return value

# *function_name: Function name is the name of the function. We can give any name to function.
# *parameter: Parameter is the value passed to the function. We can pass any number of parameters. Function body uses the 
#             parameter’s value to perform an action
# *function_body: The function body is a block of code that performs some task. This block of code is nothing but the action you 
#                 wanted to accomplish.
# *return value: Return value is the output of the function.

# %%
def message():
    print("Hello Code vibe Innovation!!")
    return "This is test message"

message()
# Out:
# Hello Code vibe Innovation!!
# 'This is test message'

# %%
def test(name,course_name):
    print("Name :",name)
    print("Course_name :",course_name)
test('Avisha','Python')
# Out:
# Name : Avisha
# Course_name : Python

# %%
# # Arbitrary Arguments, *args
# If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.

# %%
def myfunction(*course):
    print("The latest course is",course[1])

myfunction('C++','AI','pYTHON','Java','Flutter')
# Out:
# The latest course is ('C++', 'AI', 'pYTHON', 'Java', 'Flutter')

# %%
## Arbitrary Keyword Arguments, **kwargs

def myfunction(**kid):
    print("His last name is :",kid["lname"])
myfunction(fname="Avisha",lname="Patel")
# Out:
# His last name is : Patel

# %%
def details(country="india"):
    print("i am from",country)

details("Norway")
details("USA")
details()
details()
# Out:
# i am from Norway
# i am from USA
# i am from india
# i am from india

# %%
# *Functions can return a value. The return value is the output of the function. Use the return keyword to return value from a 
#  function.

def sum(x):
    return 10+x
# print(sum(10))
# print(sum(50))

sum(30)
# Out:
# 40

# %%
def even_odd(y):
    if y%2==0:
        print("even")
    else:
        print("odd")
even_odd(32)
# Out:
# even

# %%
def calculator(p,q):
    print("sum",p+q)
    return p+q
    print("sub",p-q)
    print("mul",p*q)
    print("div",p/q)
    print("modulo",p%q)
calculator(98,54)
# Out:
# sum 152
# 152

# %%
def reverse_string(y):
    return y[::-1]
input_str="code vibe innovation"
result=reverse_string(input_str)

print("reverse_string:"  ,result)
# Out:
# reverse_string: noitavonni ebiv edoc

# %%
# Write a function to find the largest of three numbers.

# Write a function to check if a string is a palindrome.

# Write a function to count the number of vowels in a string.
