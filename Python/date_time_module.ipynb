# %%
import datetime as dt

x=dt.date(2025,5,25)
print(x)
print(type(x))
# Out:
# 2025-05-25
# <class 'datetime.date'>

# %%
p=dt.date(2025,9,9)
print(p)
print(p.day)
print(p.month)
print(p.year)
print(p.isoweekday()) # mon = 1 sun = 7
print(p.weekday())    # mon = 0 sun= 6print(a)
# Out:
# 2025-09-09
# 9
# 9
# 2025
# 2
# 1

# %%
import datetime as dt
to=dt.datetime.today()
print(to)
# Out:
# 2025-09-10 13:58:12.891551

# %%
today=dt.date.today()
birthdate=dt.date(1998,8,14)
dif=today - birthdate
print(dif)
# Out:
#   Cell In[14], line 4
#     print(dif
#              ^
# _IncompleteInputError: incomplete input

# %%
today=dt.date.today()
birthdate=dt.date(1998,8,14)
dif=today-birthdate
print(dif.total_seconds())
print(dif)
# Out:
# 854323200.0
# 9888 days, 0:00:00

# %%
time = dt.time(12,15,40,500)
print(time)
print(time.minute)
print(time.second)
print(time.microsecond)
# Out:
# 12:15:40.000500
# 15
# 40
# 500

# %%
# today=dt.datetime.today()
today=dt.datetime.now()
print(today)
utc=dt.datetime.utcnow()
print(utc)
# Out:
# 2025-09-09 12:59:29.000114
# 2025-09-09 07:29:29.000295
# /var/folders/h9/cw9l68251ydb1w8yts009bdr0000gn/T/ipykernel_1036/604164056.py:4: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   utc=dt.datetime.utcnow()

# %%
import pytz
for var in pytz.all_timezones:
    print(var)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import pytz
#       2 for var in pytz.all_timezones:
#       3     print(var)
#
# ModuleNotFoundError: No module named 'pytz'

# %%
today=dt.datetime.today()
print(today)
print(today.strftime('%Y'))
print(today.strftime('%m'))
print(today.strftime('%d'))
print(today.strftime('%A'))
print(today.strftime('%a'))
print(today.strftime('%b'))
print(today.strftime('%B'))
# Out:
# 2025-09-09 13:08:59.958096
# 2025
# 09
# 09
# Tuesday
# Tue
# Sep
# September

# %%
today = dt.datetime.today()
print(today)
print(today.strftime('%b-%d-%Y'))
# Out:
# 2025-09-09 13:10:05.881196
# Sep-09-2025
