# %%
fruits=["Banana","Kiwi","Pineapple","Apple","Orange"]
print(len(fruits))
print(fruits[0:3])
print(fruits[-2:-3])
print(fruits[:-4])
print(fruits[:4:2])
print(fruits[::-1])
fruits.append("Mango")
print(fruits)
fruits.insert(2,"Cherry")
print(fruits)
f2=["Watermelon","Grapes"]
fruits.extend(f2)
print(fruits)
fruit=["Jackfruit","Pomegrante"]
allfruits=fruits+fruit
print(allfruits)
allfruits.remove("Apple")
print(allfruits)
# Out:
# 5
# ['Banana', 'Kiwi', 'Pineapple']
# []
# ['Banana']
# ['Banana', 'Pineapple']
# ['Orange', 'Apple', 'Pineapple', 'Kiwi', 'Banana']
# ['Banana', 'Kiwi', 'Pineapple', 'Apple', 'Orange', 'Mango']
# ['Banana', 'Kiwi', 'Cherry', 'Pineapple', 'Apple', 'Orange', 'Mango']
# ['Banana', 'Kiwi', 'Cherry', 'Pineapple', 'Apple', 'Orange', 'Mango', 'Watermelon', 'Grapes']
# ['Banana', 'Kiwi', 'Cherry', 'Pineapple', 'Apple', 'Orange', 'Mango', 'Watermelon', 'Grapes', 'Jackfruit', 'Pomegrante']
# ['Banana', 'Kiwi', 'Cherry', 'Pineapple', 'Orange', 'Mango', 'Watermelon', 'Grapes', 'Jackfruit', 'Pomegrante']
