# %%
#Arithamatic operator
a=int(input("enter value 1"))
b=int(input("enter value 2"))
print(a+b,a-b,a*b,a/b,a**b,a%b,a//b)
# Out:
# 7 1 12 1.3333333333333333 64 1 1

# %%
#Comparison operator
a1=int(input("enter value 1"))
b1=int(input("enter value 2"))
if a>b:
    print("grater value is",a1)
else:
    print("grater value is",b1)
if a==b:
    print("both are same")
# Out:
# grater value is 5

# %%
#logical operator
a2=int(input("enter value 1"))
if a2>=10 and a2<=20:
    print(f"{a2} is between 10 and 20")
else:
    print("not between 10 1nd 20")
# Out:
# not between 10 1nd 20

# %%
name=["avisha","hardik","parth"]
car=["swift","baleno","kia"]
print(dict.fromkeys(name,car))
# Out:
# {'avisha': ['swift', 'baleno', 'kia'], 'hardik': ['swift', 'baleno', 'kia'], 'parth': ['swift', 'baleno', 'kia']}

# %%
#identify operator
n1=45
n2=45
print(id(n1))
print(id(n2))
print(n1 is n2)
print(n1 is not n2)

c=[1,2,3,4]
d=[1,2,3,4]
print(id(c))
print(id(d))
print(c is d)
print(c is not d)
# Out:
# 140718817233192
# 140718817233192
# True
# False
# 2169591510208
# 2169591196160
# False
# True

# %%
#membership operator
c=[1,2,3,4]
print(1 in c)
print(6 in c)
print(4 not in c)
# Out:
# True
# False
# False
