# %%
# Write a function to find the largest of three numbers.

def largest_number(a,b,c):
    if a>b and a>c:
        return (f"{a} is largest number")
    elif b>c and b>a:
        return (f"{b} is largest number")
    else:
        return (f"{c} is largest number")
n1=int(input("Enter number 1"))
n2=int(input("Enter number 2"))
n3=int(input("Enter number 3"))
largest_number(n1,n2,n3)
# Out:
# '5 is largest number'

# %%
# Write a function to check if a string is a palindrome.

def palindrome_string(name):
    reverse_str=name[::-1]
    print("reverse string is ",reverse_str)
    if name==reverse_str:av
        return (f"String {name} is palindrom")
    else:
        return (f"String {name} is not palindrom")
str1=str(input("Enter any String="))
result=palindrome_string(str1)
print(result)

# %%
# Write a function to count the number of vowels in a string.

# def vowel_string(vowel):
#     vowel2=list(vowel)
#     v1=vowel2.count('a')
#     v2=vowel2.count('e')
#     v3=vowel2.count('i')
#     v4=vowel2.count('o')
#     v5=vowel2.count('u')
#     v6=vowel2.count('A')
#     v7=vowel2.count('E')
#     v8=vowel2.count('I')
#     v9=vowel2.count('O')
#     v10=vowel2.count('U')
#     vowel_count=v1+v2+v3+v4+v5+v6+v7+v8+v9+v10
#     return vowel_count
# s_t_r=str(input("Enter string"))
# total_vowel=vowel_string(s_t_r)
# print(f"Total vowel in {s_t_r} is",total_vowel)

text = "Hello World"
vowels = "aeiouAEIOU"

found_vowels = set(text) & set(vowels)
print("Vowels",found_vowels)
# Out:
# Vowels {'o', 'e'}
