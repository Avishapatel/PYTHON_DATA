# %%
import math
a=math.sqrt(36)
b=math.pow(4,3)
c=math.factorial(5)
d=math.sin(45)
e=math.sin(math.radians(4))
f=math.log(5)
g=math.exp(6)
h=math.gcd(45,75)
i=math.ceil(10.7)
j=math.floor(12.1)
print(a,  b,  c,  d,  e,  f,  g,  h,  i,  j)

k=math.pi*3
print(math.pi)
print(k)
# Out:
# 6.0 64.0 120 0.8509035245341184 0.0697564737441253 1.6094379124341003 403.4287934927351 15 11 12
# 3.141592653589793
# 9.42477796076938

# %%
import random
# print(random.randint(1,20))    #integer between 1 and 20
# print(random.random())         #float between 0 and 1
# print(random.uniform(10,100))  #float between 10 and 100


s=[1,2,3,4,5,6,7,8]
# print(random.choice(s))
# print(random.choices(s,k=9))
# print(random.sample(s,k=5))
a=random.shuffle(s)
print(a)
# Out:
# None

# %%
import random

s = [1, 2, 3, 4, 5]
a = random.shuffle(s)

print("a:", a)   # a: None
print("s:", s)   # s: [3, 1, 5, 2, 4]  (shuffled order)
# Out:
# a: None
# s: [2, 4, 3, 1, 5]
